# %%
# !pip install Seaborn
# Out:
# Collecting Seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\data science ai ml\venv\lib\site-packages (from Seaborn) (2.2.6)
# Requirement already satisfied: pandas>=1.2 in d:\data science ai ml\venv\lib\site-packages (from Seaborn) (2.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in d:\data science ai ml\venv\lib\site-packages (from Seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in d:\data science ai ml\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->Seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\data science ai ml\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->Seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\data science ai ml\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->Seaborn) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\data science ai ml\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->Seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\data science ai ml\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->Seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in d:\data science ai ml\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->Seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\data science ai ml\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->Seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in d:\data science ai ml\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->Seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\data science ai ml\venv\lib\site-packages (from pandas>=1.2->Seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\data science ai ml\venv\lib\site-packages (from pandas>=1.2->Seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\data science ai ml\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->Seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: Seaborn
# Successfully installed Seaborn-0.13.2

# %%
import seaborn as sns

# %%
# Basic Plotting with Seaborn

tips = sns.load_dataset('tips')

tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#Create a Scatter plot
import matplotlib.pyplot as plt

sns.scatterplot(x = 'total_bill',y='tip',data=tips)
plt.title("Scatter Plot of Total Bills vs Tip")
plt.show()

# %%
#Line Plot

sns.lineplot(x='sex',y='size',data=tips)
plt.title("Line plot graph sex vs size")
# Out:
# Text(0.5, 1.0, 'Line plot graph sex vs size')

# %%
#Categorical Plots

# Bar Plot

sns.barplot(x='day',y='total_bill',data=tips)
plt.title('Bar Plot of total bill by dat')
plt.show()
