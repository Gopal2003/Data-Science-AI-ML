# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in d:\data science ai ml\venv\lib\site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in d:\data science ai ml\venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\data science ai ml\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\data science ai ml\venv\lib\site-packages (from matplotlib) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\data science ai ml\venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in d:\data science ai ml\venv\lib\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in d:\data science ai ml\venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in d:\data science ai ml\venv\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\data science ai ml\venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in d:\data science ai ml\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\data science ai ml\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]

y = [1,4,9,16,25]

#Creating  a graph
plt.plot(x,y)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title("Basic Line plot")
plt.show()

# %%
x = [1,2,3,4,5]

y = [1,4,9,16,25]

#Creating a Customized Line plot
# plt.plot(x,y,color='red',linestyle='-.')
# plt.plot(x,y,color='red',linestyle='-.',marker='o')
# plt.plot(x,y,color='red',linestyle='-.',marker='o',linewidth=2)
plt.plot(x,y,color='red',linestyle='-.',marker='o',linewidth=2,markersize=9)
plt.grid(True)
