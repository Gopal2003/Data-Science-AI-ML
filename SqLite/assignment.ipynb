# %%
import sqlite3

# %%
connection = sqlite3.connect('test.db')
cursor = connection.cursor()

# %%
cursor.execute('''
    create table if not exists employees(
        id Integer,
        name text,
        age Integer,
        department text
               )
''')
